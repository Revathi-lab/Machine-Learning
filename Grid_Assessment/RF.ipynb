# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
dataset = pd.read_csv('insurance_pre.csv')

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset = pd.get_dummies(dataset,drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400     False        True
# 1      18  33.770         1   1725.55230      True       False
# 2      28  33.000         3   4449.46200      True       False
# 3      33  22.705         0  21984.47061      True       False
# 4      32  28.880         0   3866.85520      True       False
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830      True       False
# 1334   18  31.920         0   2205.98080     False       False
# 1335   18  36.850         0   1629.83350     False       False
# 1336   21  25.800         0   2007.94500     False       False
# 1337   61  29.070         0  29141.36030     False        True
#
# [1338 rows x 6 columns]

# %%
indep=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
dep=dataset['charges']

# %%
#split into training set and test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(indep, dep, test_size = 1/3, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
from sklearn.model_selection import GridSearchCV
#from sklearn.tree import DecisionTreeRegressor
param_grid = {'criterion':['squared_error', 'friedman_mse', 'poisson', 'absolute_error'],
              'max_features': ['auto','sqrt','log2'],
              'n_estimators':[10,100]} 



grid = GridSearchCV(RandomForestRegressor(), param_grid, refit = True, verbose = 3,n_jobs=-1) 
   
# fitting the model for grid search

# %%
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# C:\Anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:528: FitFailedWarning:
# 40 fits failed out of a total of 120.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 27 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#     ~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 1382, in wrapper
#     estimator._validate_params()
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 436, in _validate_params
#     validate_parameter_constraints(
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         self._parameter_constraints,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         self.get_params(deep=False),
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         caller_name=self.__class__.__name__,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "C:\Anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
#     ...<2 lines>...
#     )
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'auto' instead.
#
# --------------------------------------------------------------------------------
# 13 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#     ~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 1382, in wrapper
#     estimator._validate_params()
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 436, in _validate_params
#     validate_parameter_constraints(
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         self._parameter_constraints,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         self.get_params(deep=False),
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         caller_name=self.__class__.__name__,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "C:\Anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
#     ...<2 lines>...
#     )
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:1108: UserWarning: One or more of the test scores are non-finite: [       nan        nan 0.78035504 0.800559   0.78667392 0.79931952
#         nan        nan 0.77997132 0.80025232 0.78102669 0.79732274
#         nan        nan 0.781008   0.80148945 0.77735913 0.80069146
#         nan        nan 0.78705351 0.80121762 0.77563131 0.80118053]
#   warnings.warn(
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'poisson', 'absolute_error'],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'n_estimators': [10, 100]},
#              verbose=3)

# %%
# print best parameter after tuning 
#print(grid.best_params_) 
re=grid.cv_results_
#print(re)
grid_predictions = grid.predict(X_test) 
   
# print classification report 
from sklearn.metrics import r2_score
r_score=r2_score(y_test,grid_predictions)

print("The R_score value for best parameter {}:".format(grid.best_params_),r_score)
# Out:
# The R_score value for best parameter {'criterion': 'poisson', 'max_features': 'sqrt', 'n_estimators': 100}: 0.8736398477506679

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.001036      0.000147         0.000000        0.000000
# 1        0.001204      0.000109         0.000000        0.000000
# 2        0.060007      0.010194         0.006315        0.001088
# 3        0.420916      0.020000         0.026218        0.001898
# 4        0.089827      0.008242         0.006349        0.001664
# 5        0.419921      0.035163         0.025669        0.001160
# 6        0.003863      0.003048         0.000000        0.000000
# 7        0.001269      0.000341         0.000000        0.000000
# 8        0.046946      0.010478         0.005786        0.001067
# 9        0.388502      0.023648         0.025115        0.000976
# 10       0.046961      0.006040         0.004462        0.000448
# 11       0.367277      0.012613         0.023997        0.001047
# 12       0.001395      0.000467         0.000000        0.000000
# 13       0.001166      0.000064         0.000000        0.000000
# 14       0.043809      0.001945         0.004565        0.000360
# 15       0.384370      0.008833         0.022754        0.000568
# 16       0.042320      0.000384         0.004485        0.000208
# 17       0.382541      0.016650         0.023952        0.001538
# 18       0.001193      0.000175         0.000000        0.000000
# 19       0.001133      0.000110         0.000000        0.000000
# 20       0.101612      0.002849         0.004365        0.000097
# 21       0.901729      0.023843         0.022234        0.000706
# 22       0.098107      0.004204         0.004567        0.000727
# 23       0.860460      0.019357         0.019196        0.003331
#
#    param_criterion param_max_features  param_n_estimators  \
# 0    squared_error               auto                  10
# 1    squared_error               auto                 100
# 2    squared_error               sqrt                  10
# 3    squared_error               sqrt                 100
# 4    squared_error               log2                  10
# 5    squared_error               log2                 100
# 6     friedman_mse               auto                  10
# 7     friedman_mse               auto                 100
# 8     friedman_mse               sqrt                  10
# 9     friedman_mse               sqrt                 100
# 10    friedman_mse               log2                  10
# 11    friedman_mse               log2                 100
# 12         poisson               auto                  10
# 13         poisson               auto                 100
# 14         poisson               sqrt                  10
# 15         poisson               sqrt                 100
# 16         poisson               log2                  10
# 17         poisson               log2                 100
# 18  absolute_error               auto                  10
# 19  absolute_error               auto                 100
# 20  absolute_error               sqrt                  10
# 21  absolute_error               sqrt                 100
# 22  absolute_error               log2                  10
# 23  absolute_error               log2                 100
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...                NaN
# 1   {'criterion': 'squared_error', 'max_features':...                NaN
# 2   {'criterion': 'squared_error', 'max_features':...           0.784885
# 3   {'criterion': 'squared_error', 'max_features':...           0.806937
# 4   {'criterion': 'squared_error', 'max_features':...           0.786796
# 5   {'criterion': 'squared_error', 'max_features':...           0.806684
# 6   {'criterion': 'friedman_mse', 'max_features': ...                NaN
# 7   {'criterion': 'friedman_mse', 'max_features': ...                NaN
# 8   {'criterion': 'friedman_mse', 'max_features': ...           0.784712
# 9   {'criterion': 'friedman_mse', 'max_features': ...           0.806922
# 10  {'criterion': 'friedman_mse', 'max_features': ...           0.763242
# 11  {'criterion': 'friedman_mse', 'max_features': ...           0.802167
# 12  {'criterion': 'poisson', 'max_features': 'auto...                NaN
# 13  {'criterion': 'poisson', 'max_features': 'auto...                NaN
# 14  {'criterion': 'poisson', 'max_features': 'sqrt...           0.761113
# 15  {'criterion': 'poisson', 'max_features': 'sqrt...           0.809214
# 16  {'criterion': 'poisson', 'max_features': 'log2...           0.759506
# 17  {'criterion': 'poisson', 'max_features': 'log2...           0.806721
# 18  {'criterion': 'absolute_error', 'max_features'...                NaN
# 19  {'criterion': 'absolute_error', 'max_features'...                NaN
# 20  {'criterion': 'absolute_error', 'max_features'...           0.789887
# 21  {'criterion': 'absolute_error', 'max_features'...           0.802395
# 22  {'criterion': 'absolute_error', 'max_features'...           0.796948
# 23  {'criterion': 'absolute_error', 'max_features'...           0.810162
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0                 NaN                NaN                NaN
# 1                 NaN                NaN                NaN
# 2            0.735492           0.828093           0.803665
# 3            0.769516           0.833840           0.833603
# 4            0.763625           0.837797           0.812715
# 5            0.764776           0.834351           0.833603
# 6                 NaN                NaN                NaN
# 7                 NaN                NaN                NaN
# 8            0.750787           0.801629           0.815933
# 9            0.772240           0.835025           0.829212
# 10           0.765171           0.825283           0.808324
# 11           0.759657           0.837711           0.825239
# 12                NaN                NaN                NaN
# 13                NaN                NaN                NaN
# 14           0.756094           0.837155           0.801791
# 15           0.771935           0.833106           0.828033
# 16           0.742471           0.819087           0.812075
# 17           0.768338           0.834998           0.831344
# 18                NaN                NaN                NaN
# 19                NaN                NaN                NaN
# 20           0.750668           0.820413           0.829329
# 21           0.775866           0.838073           0.827692
# 22           0.722016           0.840533           0.769965
# 23           0.774539           0.839421           0.818842
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0                 NaN              NaN             NaN               17
# 1                 NaN              NaN             NaN               17
# 2            0.749640         0.780355        0.034056               13
# 3            0.758899         0.800559        0.031431                5
# 4            0.732437         0.786674        0.036782               10
# 5            0.757185         0.799320        0.032941                7
# 6                 NaN              NaN             NaN               17
# 7                 NaN              NaN             NaN               17
# 8            0.746796         0.779971        0.027339               14
# 9            0.757864         0.800252        0.030574                6
# 10           0.743113         0.781027        0.030688               11
# 11           0.761841         0.797323        0.031974                8
# 12                NaN              NaN             NaN               17
# 13                NaN              NaN             NaN               17
# 14           0.748888         0.781008        0.033564               12
# 15           0.765159         0.801489        0.028132                1
# 16           0.753657         0.777359        0.031762               15
# 17           0.762057         0.800691        0.030634                4
# 18                NaN              NaN             NaN               17
# 19                NaN              NaN             NaN               17
# 20           0.744970         0.787054        0.034650                9
# 21           0.762062         0.801218        0.029108                2
# 22           0.748694         0.775631        0.040740               16
# 23           0.762939         0.801181        0.028380                3

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age: 40
# BMI: 2
# Children: 2
# Sex Male 0 or 1: 0
# Smoker Yes 0 or 1: 0

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])# change the paramter,play with it.
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[15139.3342461]
